# %% [markdown]
# ## Tutorial Taken from:
# https://medium.com/analytics-vidhya/topic-modeling-using-gensim-lda-in-python-48eaa2344920

# %%
"""Import libraries"""
import nltk
import re
import numpy as np
import pandas as  pd
from pprint import pprint# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel# spaCy for preprocessing
import spacy# Plotting tools
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/jcm/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
"""Prepare stopwords"""

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
"""Load dataset"""
# LoadDataset
file_path = "./enr-processed.jsonl"

df = pd.read_json(file_path, lines=True)
print(f"Number of articles:  {df.shape[0]}")
df.head()
# Out:
# Number of articles:  43105
#                                                  url  \
# 0  https://www.enr.com/articles/58087-autodesk-re...
# 1  https://www.enr.com/articles/58107-constructio...
# 2  https://www.enr.com/articles/58108-776m-broadw...
# 3  https://www.enr.com/articles/58106-mccarthy-st...
# 4  https://www.enr.com/articles/58109-in-final-ru...
#
#                                                title  \
# 0  Autodesk Releases Informed Design, an Inventor...
# 1       Construction Economics for February 12, 2024
# 2  $776M Broadway Curve Job Among Projects Revamp...
# 3  McCarthy Standardizes its Payments Using Oracl...
# 4  In Final Rule, EPA Tightens Air Quality Standa...
#
#                                                 text      publish_date  \
# 0  On February 7, Autodesk released Informed Desi...  February 7, 2024
# 1  The shifting market landscape is transforming ...  February 7, 2024
# 2  The Arizona Dept. of Transportation will conti...  February 7, 2024
# 3  As cloud-based construction payments continue ...  February 7, 2024
# 4  In a move it says will improve the health of m...  February 7, 2024
#
#                                             keywords  \
# 0  [News, Tech, Building Information Modeling (BIM)]
# 1    [Projects, Costs, Construction Economics, 2024]
# 2  [Projects, Southwest, Southwest Construction N...
# 3  [Business, Tech, Companies, Information techno...
# 4                       [News, Business, Government]
#
#                                        meta_keywords  \
# 0  [BIM, Manufacturing in Construction, PLM and BIM]
# 1                      [Economics, Materials Prices]
# 2                 [Transportation, Highways/Bridges]
# 3        [McCarthy Building Cos., Payments, Textura]
# 4          [EPA, soot, Environmental Justice, NAAQS]
#
#                                     meta_description
# 0  Autodesk has released Informed Design, add-ons...
# 1  ENR’s 20-city average cost indexes, wages and ...
# 2  Projects totaling more than $1.3 billion are r...
# 3  McCarthy Building Cos. has standardized its su...
# 4  The tighter air pollution standard was long so...

# %%
"""Data cleaning:  Remove emails and newlines"""
# Convert to list 
data = df.text.values.tolist()  
# Remove new line characters 
data = [re.sub('\s+', ' ', sent) for sent in data]  
# Remove distracting single quotes 
data = [re.sub("\'", "", sent) for sent in data]  
pprint(data[:1])
# Out:
# <>:5: DeprecationWarning: invalid escape sequence '\s'
# <>:5: DeprecationWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1836238/2812757616.py:5: DeprecationWarning: invalid escape sequence '\s'
#   data = [re.sub('\s+', ' ', sent) for sent in data]
# ['On February 7, Autodesk released Informed Design, a pair of add-ons for the '
#  'companys building information modeling and product design authoring tools '
#  'intended to better automate the process of product design and placement of '
#  'mechanical assemblies and other complex products into 3D building and '
#  'infrastructure models. Autodesk says Informed Design connects design and '
#  'manufacturing workflows, and will allow designers to specify products and '
#  'assemblies that were created in Inventor, the companys manufacturing '
#  'authoring tool, into Revit, its parametric BIM tool. This is a functionality '
#  'that Autodesk says architects and engineers have been demanding for a long '
#  'time. "Informed Design improves certainty," said Ryan McMahon, general '
#  'manager manufacturing/Informed Design at Autodesk during a press event '
#  'announcing the product. "Productization is the key concept that makes this '
#  'possible. Fabricators and subcontractors will define their products '
#  'including all the ways they can be varied but remain manufacturable. These '
#  'products are then published so that architects can discover and use them '
#  'during design." From Inventor to Revit The workflow uses Autodesks '
#  'Construction Cloud collaboration platform as a go-between for Inventor and '
#  'Revit. McMahon said Autodesk does not plan to make a direct workflow '
#  'available. McMahon explained that Informed Design is an add-in that allows '
#  'Inventor to export fully-formed Revit families as an output. "A shortcoming '
#  'of Inventor is that it has not in the past produced outputs that have '
#  'categories, family names, void bodies, coordinate systems, things like '
#  'that," he said. While Informed Design will allow customers to use Inventor '
#  'to create a Revit family, manually placing that Revit family inside a Revit '
#  'project will require Construction Cloud, which Autodesk uses to store '
#  'templates and project data. "The capability around defining the rules for a '
#  'template and enforcing those rules necessitates using our solution to take '
#  'advantage of the authoring and enforcement components." McMahon said. '
#  'Informed Design for Inventor allows building product design engineers to '
#  'automate the process of creating models of building products such as '
#  'mechanical equipment and assemblies for components such as unitized '
#  'curtainwall, and even building components such as escalators. Informed '
#  'Design for Revit allows architects, engineers and virtual design and '
#  'construction professionals to then place those building products into their '
#  'models. Because they can see how the 3D parametric building product objects '
#  'fit into the overall project, users can perform basic clash detection and '
#  'constructability assessments. Being able to confirm that specified building '
#  'products meet project requirements and are compatible with other installed '
#  'components and meet industry standards was another longtime demand of '
#  'Autodesk users in the design world. On-Demand Pricing McMahon said that '
#  'while users will need Revit, Inventor and Construction Cloud to use Informed '
#  'Design, the add-on will be available with no upfront charge. Informed Design '
#  'will be part of Autodesk’s Design and Make Platform environment. '
#  '"Ultimately, we will wind up charging on generating output," he said. "We '
#  'dont want to charge for authoring products. We dont want to charge for '
#  'placing an instance of a product in a building project. But when you want to '
#  'create a bill of materials, shop drawings or other formats used to fabricate '
#  'it, we think that that is a point in which we have created value for our '
#  'customers. That feels like the right thing to monetize. And so we will plan '
#  'on having a token rate based on the outputs that you create." Several '
#  'Autodesk customers began testing Informed Design in the second half of 2023. '
#  '"Autodesk Informed Design has shown that there’s a way to bring customized '
#  'details, good aesthetics and quality engineering into a product that can be '
#  'mass produced," said Benjamin Hall, senior product manager at Green Canopy '
#  'NODE, a sustainability consultant that works mainly with the design of green '
#  'homes. “Designing with constraints doesn’t curb my creativity—it gives me '
#  'choices I know will work." International Data Corporation (IDC), a provider '
#  'of market intelligence, advisory services, and events for the information '
#  'technology, telecommunications, and consumer technology markets has been '
#  'testing its workflows with Informed Design. "Through a connected, '
#  'bidirectional digital thread and sharing of data across the AECO ecosystem '
#  'of partners, it is easier to optimize supplier performance and deliver '
#  'quality products and services that complement the overall design of a '
#  'building," said Jeffrey Hojlo, research vice president, Future of Industry '
#  'Ecosystems & Energy Insight at IDC. Autodesk said both add-ons will be '
#  'available Feb. 7 for their respective authoring tools and via Construction '
#  'Cloud. The company also released a 90-second explainer video for Informed '
#  'Design.']

# %%
"""Tokenization and cleaning up text"""
def sent_to_words(sentences):
  for sentence in sentences:
    yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))            #deacc=True removes punctuations
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['on', 'february', 'autodesk', 'released', 'informed', 'design', 'pair', 'of', 'add', 'ons', 'for', 'the', 'companys', 'building', 'information', 'modeling', 'and', 'product', 'design', 'authoring', 'tools', 'intended', 'to', 'better', 'automate', 'the', 'process', 'of', 'product', 'design', 'and', 'placement', 'of', 'mechanical', 'assemblies', 'and', 'other', 'complex', 'products', 'into', 'building', 'and', 'infrastructure', 'models', 'autodesk', 'says', 'informed', 'design', 'connects', 'design', 'and', 'manufacturing', 'workflows', 'and', 'will', 'allow', 'designers', 'to', 'specify', 'products', 'and', 'assemblies', 'that', 'were', 'created', 'in', 'inventor', 'the', 'companys', 'manufacturing', 'authoring', 'tool', 'into', 'revit', 'its', 'parametric', 'bim', 'tool', 'this', 'is', 'functionality', 'that', 'autodesk', 'says', 'architects', 'and', 'engineers', 'have', 'been', 'demanding', 'for', 'long', 'time', 'informed', 'design', 'improves', 'certainty', 'said', 'ryan', 'mcmahon', 'general', 'manager', 'manufacturing', 'informed', 'design', 'at', 'autodesk', 'during', 'press', 'event', 'announcing', 'the', 'product', 'productization', 'is', 'the', 'key', 'concept', 'that', 'makes', 'this', 'possible', 'fabricators', 'and', 'subcontractors', 'will', 'define', 'their', 'products', 'including', 'all', 'the', 'ways', 'they', 'can', 'be', 'varied', 'but', 'remain', 'manufacturable', 'these', 'products', 'are', 'then', 'published', 'so', 'that', 'architects', 'can', 'discover', 'and', 'use', 'them', 'during', 'design', 'from', 'inventor', 'to', 'revit', 'the', 'workflow', 'uses', 'autodesks', 'construction', 'cloud', 'collaboration', 'platform', 'as', 'go', 'between', 'for', 'inventor', 'and', 'revit', 'mcmahon', 'said', 'autodesk', 'does', 'not', 'plan', 'to', 'make', 'direct', 'workflow', 'available', 'mcmahon', 'explained', 'that', 'informed', 'design', 'is', 'an', 'add', 'in', 'that', 'allows', 'inventor', 'to', 'export', 'fully', 'formed', 'revit', 'families', 'as', 'an', 'output', 'shortcoming', 'of', 'inventor', 'is', 'that', 'it', 'has', 'not', 'in', 'the', 'past', 'produced', 'outputs', 'that', 'have', 'categories', 'family', 'names', 'void', 'bodies', 'coordinate', 'systems', 'things', 'like', 'that', 'he', 'said', 'while', 'informed', 'design', 'will', 'allow', 'customers', 'to', 'use', 'inventor', 'to', 'create', 'revit', 'family', 'manually', 'placing', 'that', 'revit', 'family', 'inside', 'revit', 'project', 'will', 'require', 'construction', 'cloud', 'which', 'autodesk', 'uses', 'to', 'store', 'templates', 'and', 'project', 'data', 'the', 'capability', 'around', 'defining', 'the', 'rules', 'for', 'template', 'and', 'enforcing', 'those', 'rules', 'necessitates', 'using', 'our', 'solution', 'to', 'take', 'advantage', 'of', 'the', 'authoring', 'and', 'enforcement', 'components', 'mcmahon', 'said', 'informed', 'design', 'for', 'inventor', 'allows', 'building', 'product', 'design', 'engineers', 'to', 'automate', 'the', 'process', 'of', 'creating', 'models', 'of', 'building', 'products', 'such', 'as', 'mechanical', 'equipment', 'and', 'assemblies', 'for', 'components', 'such', 'as', 'unitized', 'curtainwall', 'and', 'even', 'building', 'components', 'such', 'as', 'escalators', 'informed', 'design', 'for', 'revit', 'allows', 'architects', 'engineers', 'and', 'virtual', 'design', 'and', 'construction', 'professionals', 'to', 'then', 'place', 'those', 'building', 'products', 'into', 'their', 'models', 'because', 'they', 'can', 'see', 'how', 'the', 'parametric', 'building', 'product', 'objects', 'fit', 'into', 'the', 'overall', 'project', 'users', 'can', 'perform', 'basic', 'clash', 'detection', 'and', 'assessments', 'being', 'able', 'to', 'confirm', 'that', 'specified', 'building', 'products', 'meet', 'project', 'requirements', 'and', 'are', 'compatible', 'with', 'other', 'installed', 'components', 'and', 'meet', 'industry', 'standards', 'was', 'another', 'longtime', 'demand', 'of', 'autodesk', 'users', 'in', 'the', 'd ...

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['on', 'february', 'autodesk', 'released', 'informed', 'design', 'pair', 'of', 'add_ons', 'for', 'the', 'companys', 'building', 'information_modeling', 'and', 'product', 'design', 'authoring_tools', 'intended', 'to', 'better', 'automate', 'the', 'process', 'of', 'product', 'design', 'and', 'placement', 'of', 'mechanical', 'assemblies', 'and', 'other', 'complex', 'products', 'into', 'building', 'and', 'infrastructure', 'models', 'autodesk', 'says', 'informed', 'design', 'connects', 'design', 'and', 'manufacturing', 'workflows', 'and', 'will', 'allow', 'designers', 'to', 'specify', 'products', 'and', 'assemblies', 'that', 'were', 'created', 'in', 'inventor', 'the', 'companys', 'manufacturing', 'authoring_tool', 'into', 'revit', 'its', 'parametric', 'bim', 'tool', 'this', 'is', 'functionality', 'that', 'autodesk', 'says', 'architects', 'and', 'engineers', 'have', 'been', 'demanding', 'for', 'long', 'time', 'informed', 'design', 'improves', 'certainty', 'said', 'ryan', 'mcmahon', 'general', 'manager', 'manufacturing', 'informed', 'design', 'at', 'autodesk', 'during', 'press', 'event', 'announcing', 'the', 'product', 'productization', 'is', 'the', 'key', 'concept', 'that', 'makes', 'this', 'possible', 'fabricators', 'and', 'subcontractors', 'will', 'define', 'their', 'products', 'including', 'all', 'the', 'ways', 'they', 'can', 'be', 'varied', 'but', 'remain', 'manufacturable', 'these', 'products', 'are', 'then', 'published', 'so', 'that', 'architects', 'can', 'discover', 'and', 'use', 'them', 'during', 'design', 'from', 'inventor', 'to', 'revit', 'the', 'workflow', 'uses', 'autodesks', 'construction', 'cloud', 'collaboration', 'platform', 'as', 'go', 'between', 'for', 'inventor', 'and', 'revit', 'mcmahon', 'said', 'autodesk', 'does', 'not', 'plan', 'to', 'make', 'direct', 'workflow', 'available', 'mcmahon', 'explained', 'that', 'informed', 'design', 'is', 'an', 'add', 'in', 'that', 'allows', 'inventor', 'to', 'export', 'fully', 'formed', 'revit', 'families', 'as', 'an', 'output', 'shortcoming', 'of', 'inventor', 'is', 'that', 'it', 'has', 'not', 'in', 'the', 'past', 'produced', 'outputs', 'that', 'have', 'categories', 'family', 'names', 'void', 'bodies', 'coordinate', 'systems', 'things', 'like', 'that', 'he', 'said', 'while', 'informed', 'design', 'will', 'allow', 'customers', 'to', 'use', 'inventor', 'to', 'create', 'revit', 'family', 'manually', 'placing', 'that', 'revit', 'family', 'inside', 'revit', 'project', 'will', 'require', 'construction', 'cloud', 'which', 'autodesk', 'uses', 'to', 'store', 'templates', 'and', 'project', 'data', 'the', 'capability', 'around', 'defining', 'the', 'rules', 'for', 'template', 'and', 'enforcing', 'those', 'rules', 'necessitates', 'using', 'our', 'solution', 'to', 'take_advantage', 'of', 'the', 'authoring', 'and', 'enforcement', 'components', 'mcmahon', 'said', 'informed', 'design', 'for', 'inventor', 'allows', 'building', 'product', 'design', 'engineers', 'to', 'automate', 'the', 'process', 'of', 'creating', 'models', 'of', 'building', 'products', 'such', 'as', 'mechanical', 'equipment', 'and', 'assemblies', 'for', 'components', 'such', 'as', 'unitized', 'curtainwall', 'and', 'even', 'building', 'components', 'such', 'as', 'escalators', 'informed', 'design', 'for', 'revit', 'allows', 'architects', 'engineers', 'and', 'virtual', 'design', 'and', 'construction', 'professionals', 'to', 'then', 'place', 'those', 'building', 'products', 'into', 'their', 'models', 'because', 'they', 'can', 'see', 'how', 'the', 'parametric', 'building', 'product', 'objects', 'fit', 'into', 'the', 'overall', 'project', 'users', 'can', 'perform', 'basic', 'clash_detection', 'and', 'assessments', 'being', 'able', 'to', 'confirm', 'that', 'specified', 'building', 'products', 'meet', 'project', 'requirements', 'and', 'are', 'compatible', 'with', 'other', 'installed', 'components', 'and', 'meet', 'industry', 'standards', 'was', 'another', 'longtime', 'demand', 'of', 'autodesk', 'users', 'in', 'the', 'design', 'world', 'o ...

# %%
"""Remove stopwords, make bigrams, lemmatize"""
# Define function for stopwords, bigrams, trigrams and lemmatization
import math
len_segments = 100

def remove_stopwords(texts):
    return_ls = []
    num_segments = int(math.ceil(len(texts)/len_segments))
    
    for i in range(num_segments):
        start_i = i*len_segments
        end_i = start_i + len_segments
        text_segment = texts[start_i : end_i]
        
        print(f"removing stopwords from {start_i} through {end_i}")
        return_ls.extend([[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in text_segment])
    return return_ls

def make_bigrams(texts):
    return_ls = []
    num_segments = int(math.ceil(len(texts)/len_segments))
    
    for i in range(num_segments):
        start_i = i*len_segments
        end_i = start_i + len_segments
        text_segment = texts[start_i : end_i]
        
        print(f"making bigrams from {start_i} through {end_i}")
        return_ls.extend([bigram_mod[doc] for doc in text_segment])
    
    return return_ls

def make_trigrams(texts):
    return_ls = []
    num_segments = int(math.ceil(len(texts)/len_segments))
    
    for i in range(num_segments):
        start_i = i*len_segments
        end_i = start_i + len_segments
        text_segment = texts[start_i : end_i]
        
        print(f"removing make trigram from {start_i} through {end_i}")
        return_ls.extend([bigram_mod[doc] for doc in text_segment])
    
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for i, sent in enumerate(texts):
        if i % len_segments == 0:
            start_i = i*len_segments
            end_i = start_i + len_segments
            print(f"removing make trigram from {start_i} through {end_i}")
        
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# removing stopwords from 0 through 100
# removing stopwords from 100 through 200
# removing stopwords from 200 through 300
# removing stopwords from 300 through 400
# removing stopwords from 400 through 500
# removing stopwords from 500 through 600
# removing stopwords from 600 through 700
# removing stopwords from 700 through 800
# removing stopwords from 800 through 900
# removing stopwords from 900 through 1000
# removing stopwords from 1000 through 1100
# removing stopwords from 1100 through 1200
# removing stopwords from 1200 through 1300
# removing stopwords from 1300 through 1400
# removing stopwords from 1400 through 1500
# removing stopwords from 1500 through 1600
# removing stopwords from 1600 through 1700
# removing stopwords from 1700 through 1800
# removing stopwords from 1800 through 1900
# removing stopwords from 1900 through 2000
# removing stopwords from 2000 through 2100
# removing stopwords from 2100 through 2200
# removing stopwords from 2200 through 2300
# removing stopwords from 2300 through 2400
# removing stopwords from 2400 through 2500
# removing stopwords from 2500 through 2600
# removing stopwords from 2600 through 2700
# removing stopwords from 2700 through 2800
# removing stopwords from 2800 through 2900
# removing stopwords from 2900 through 3000
# removing stopwords from 3000 through 3100
# removing stopwords from 3100 through 3200
# removing stopwords from 3200 through 3300
# removing stopwords from 3300 through 3400
# removing stopwords from 3400 through 3500
# removing stopwords from 3500 through 3600
# removing stopwords from 3600 through 3700
# removing stopwords from 3700 through 3800
# removing stopwords from 3800 through 3900
# removing stopwords from 3900 through 4000
# removing stopwords from 4000 through 4100
# removing stopwords from 4100 through 4200
# removing stopwords from 4200 through 4300
# removing stopwords from 4300 through 4400
# removing stopwords from 4400 through 4500
# removing stopwords from 4500 through 4600
# removing stopwords from 4600 through 4700
# removing stopwords from 4700 through 4800
# removing stopwords from 4800 through 4900
# removing stopwords from 4900 through 5000
# removing stopwords from 5000 through 5100
# removing stopwords from 5100 through 5200
# removing stopwords from 5200 through 5300
# removing stopwords from 5300 through 5400
# removing stopwords from 5400 through 5500
# removing stopwords from 5500 through 5600
# removing stopwords from 5600 through 5700
# removing stopwords from 5700 through 5800
# removing stopwords from 5800 through 5900
# removing stopwords from 5900 through 6000
# removing stopwords from 6000 through 6100
# removing stopwords from 6100 through 6200
# removing stopwords from 6200 through 6300
# removing stopwords from 6300 through 6400
# removing stopwords from 6400 through 6500
# removing stopwords from 6500 through 6600
# removing stopwords from 6600 through 6700
# removing stopwords from 6700 through 6800
# removing stopwords from 6800 through 6900
# removing stopwords from 6900 through 7000
# removing stopwords from 7000 through 7100
# removing stopwords from 7100 through 7200
# removing stopwords from 7200 through 7300
# removing stopwords from 7300 through 7400
# removing stopwords from 7400 through 7500
# removing stopwords from 7500 through 7600
# removing stopwords from 7600 through 7700
# removing stopwords from 7700 through 7800
# removing stopwords from 7800 through 7900
# removing stopwords from 7900 through 8000
# removing stopwords from 8000 through 8100
# removing stopwords from 8100 through 8200
# removing stopwords from 8200 through 8300
# removing stopwords from 8300 through 8400
# removing stopwords from 8400 through 8500
# removing stopwords from 8500 through 8600
# removing stopwords from 8600 through 8700
# removing stopwords from 8700 through 8800
# removing stopwords from 8800 through 8900
# removing stopwords from 8900 through 9000
# removing stopwords from 9000 through 9100
# removing stopwords from 9100 through 9200
# removing stopwords from 9200 through 9300
# removing stopwords from 9300 through 9400
# removing stopwords from 9400 through 9500
# removing stopwords from 9500 through 9600
# removing stopwords from 9600 through 9700
# removing stopwords from 9700 through 9800
# removing stopwords from 9800 through 9900
# removing stopwords from 9900 through 10000
# removing stopwords from 10000 through 10100
# removing stopwords from 10100 through 10200
# removing stopwords from 10200 through 10300
# removing stopwords from 10300 through 10400
# removing stopwords from 10400 through 10500
# removing stopwords from 10500 through 10600
# removing stopwords from 10600 through 10700
# removing stopwords from 10700 through 10800
# removing stopwords from 10800 through 10900
# removing stopwords from 10900 through 11000
# removing stopwords from 11000 through 11100
# removing stopwords from 11100 through 11200
# removing stopwords from 11200 through 11300
# removing stopwords from 11300 through 11400
# removing stopwords from 11400 through 11500
# removing stopwords from 11500 through 11600
# removing stopwords from 11600 through 11700
# removing stopwords from 11700 through 11800
# removing stopwords from 11800 through 11900
# removing stopwords from 11900 through 12000
# removing stopwords from 12000 through 12100
# removing stopwords from 12100 through 12200
# removing stopwords from 12200 through 12300
# removing stopwords from 12300 through 12400
# removing stopwords from 12400 through 12500
# removing stopwords from 12500 through 12600
# removing stopwords from 12600 through 12700
# removing stopwords from 12700 through 12800
# removing stopwords from 12800 through 12900
# removing stopwords from 12900 through 13000
# removing stopwords from 13000 through 13100
# removing stopwords from 13100 through 13200
# removing stopwords from 13200 through 13300
# removing stopwords from 13300 through 13400
# removing stopwords from 13400 through 13500
# removing stopwords from 13500 through 13600
# removing stopwords from 13600 through 13700
# removing stopwords from 13700 through 13800
# removing stopwords from 13800 through 13900
# removing stopwords from 13900 through 14000
# removing stopwords from 14000 through 14100
# removing stopwords from 14100 through 14200
# removing stopwords from 14200 through 14300
# removing stopwords from 14300 through 14400
# removing stopwords from 14400 through 14500
# removing stopwords from 14500 through 14600
# removing stopwords from 14600 through 14700
# removing stopwords from 14700 through 14800
# removing stopwords from 14800 through 14900
# removing stopwords from 14900 through 15000
# removing stopwords from 15000 through 15100
# removing stopwords from 15100 through 15200
# removing stopwords from 15200 through 15300
# removing stopwords from 15300 through 15400
# removing stopwords from 15400 through 15500
# removing stopwords from 15500 through 15600
# removing stopwords from 15600 through 15700
# removing stopwords from 15700 through 15800
# removing stopwords from 15800 through 15900
# removing stopwords from 15900 through 16000
# removing stopwords from 16000 through 16100
# removing stopwords from 16100 through 16200
# removing stopwords from 16200 through 16300
# removing stopwords from 16300 through 16400
# removing stopwords from 16400 through 16500
# removing stopwords from 16500 through 16600
# removing stopwords from 16600 through 16700
# removing stopwords from 16700 through 16800
# removing stopwords from 16800 through 16900
# removing stopwords from 16900 through 17000
# removing stopwords from 17000 through 17100
# removing stopwords from 17100 through 17200
# removing stopwords from 17200 through 17300
# removing stopwords from 17300 through 17400
# removing stopwords from 17400 through 17500
# removing stopwords from 17500 through 17600
# removing stopwords from 17600 through 17700
# removing stopwords from 17700 through 17800
# removing stopwords from 17800 through 17900
# removing stopwords from 17900 through 18000
# removing stopwords from 18000 through 18100
# removing stopwords from 18100 through 18200
# removing stopwords from 18200 through 18300
# removing stopwords from 18300 through 18400
# removing stopwords from 18400 through 18500
# removing stopwords from 18500 through 18600
# removing stopwords from 18600 through 18700
# removing stopwords from 18700 through 18800
# removing stopwords from 18800 through 18900
# removing stopwords from 18900 through 19000
# removing stopwords from 19000 through 19100
# removing stopwords from 19100 through 19200
# removing stopwords from 19200 through 19300
# removing stopwords from 19300 through 19400
# removing stopwords from 19400 through 19500
# removing stopwords from 19500 through 19600
# removing stopwords from 19600 through 19700
# removing stopwords from 19700 through 19800
# removing stopwords from 19800 through 19900
# removing stopwords from 19900 through 20000
# removing stopwords from 20000 through 20100
# removing stopwords from 20100 through 20200
# removing stopwords from 20200 through 20300
# removing stopwords from 20300 through 20400
# removing stopwords from 20400 through 20500
# removing stopwords from 20500 through 20600
# removing stopwords from 20600 through 20700
# removing stopwords from 20700 through 20800
# removing stopwords from 20800 through 20900
# removing stopwords from 20900 through 21000
# removing stopwords from 21000 through 21100
# removing stopwords from 21100 through 21200
# removing stopwords from 21200 through 21300
# removing stopwords from 21300 through 21400
# removing stopwords from 21400 through 21500
# removing stopwords from 21500 through 21600
# removing stopwords from 21600 through 21700
# removing stopwords from 21700 through 21800
# removing stopwords from 21800 through 21900
# removing stopwords from 21900 through 22000
# removing stopwords from 22000 through 22100
# removing stopwords from 22100 through 22200
# removing stopwords from 22200 through 22300
# removing stopwords from 22300 through 22400
# removing stopwords from 22400 through 22500
# removing stopwords from 22500 through 22600
# removing stopwords from 22600 through 22700
# removing stopwords from 22700 through 22800
# removing stopwords from 22800 through 22900
# removing stopwords from 22900 through 23000
# removing stopwords from 23000 through 23100
# removing stopwords from 23100 through 23200
# removing stopwords from 23200 through 23300
# removing stopwords from 23300 through 23400
# removing stopwords from 23400 through 23500
# removing stopwords from 23500 through 23600
# removing stopwords from 23600 through 23700
# removing stopwords from 23700 through 23800
# removing stopwords from 23800 through 23900
# removing stopwords from 23900 through 24000
# removing stopwords from 24000 through 24100
# removing stopwords from 24100 through 24200
# removing stopwords from 24200 through 24300
# removing stopwords from 24300 through 24400
# removing stopwords from 24400 through 24500
# removing stopwords from 24500 through 24600
# removing stopwords from 24600 through 24700
# removing stopwords from 24700 through 24800
# removing stopwords from 24800 through 24900
# removing stopwords from 24900 through 25000
# removing stopwords from 25000 through 25100
# removing stopwords from 25100 through 25200
# removing stopwords from 25200 through 25300
# removing stopwords from 25300 through 25400
# removing stopwords from 25400 through 25500
# removing stopwords from 25500 through 25600
# removing stopwords from 25600 through 25700
# removing stopwords from 25700 through 25800
# removing stopwords from 25800 through 25900
# removing stopwords from 25900 through 26000
# removing stopwords from 26000 through 26100
# removing stopwords from 26100 through 26200
# removing stopwords from 26200 through 26300
# removing stopwords from 26300 through 26400
# removing stopwords from 26400 through 26500
# removing stopwords from 26500 through 26600
# removing stopwords from 26600 through 26700
# removing stopwords from 26700 through 26800
# removing stopwords from 26800 through 26900
# removing stopwords from 26900 through 27000
# removing stopwords from 27000 through 27100
# removing stopwords from 27100 through 27200
# removing stopwords from 27200 through 27300
# removing stopwords from 27300 through 27400
# removing stopwords from 27400 through 27500
# removing stopwords from 27500 through 27600
# removing stopwords from 27600 through 27700
# removing stopwords from 27700 through 27800
# removing stopwords from 27800 through 27900
# removing stopwords from 27900 through 28000
# removing stopwords from 28000 through 28100
# removing stopwords from 28100 through 28200
# removing stopwords from 28200 through 28300
# removing stopwords from 28300 through 28400
# removing stopwords from 28400 through 28500
# removing stopwords from 28500 through 28600
# removing stopwords from 28600 through 28700
# removing stopwords from 28700 through 28800
# removing stopwords from 28800 through 28900
# removing stopwords from 28900 through 29000
# removing stopwords from 29000 through 29100
# removing stopwords from 29100 through 29200
# removing stopwords from 29200 through 29300
# removing stopwords from 29300 through 29400
# removing stopwords from 29400 through 29500
# removing stopwords from 29500 through 29600
# removing stopwords from 29600 through 29700
# removing stopwords from 29700 through 29800
# removing stopwords from 29800 through 29900
# removing stopwords from 29900 through 30000
# removing stopwords from 30000 through 30100
# removing stopwords from 30100 through 30200
# removing stopwords from 30200 through 30300
# removing stopwords from 30300 through 30400
# removing stopwords from 30400 through 30500
# removing stopwords from 30500 through 30600
# removing stopwords from 30600 through 30700
# removing stopwords from 30700 through 30800
# removing stopwords from 30800 through 30900
# removing stopwords from 30900 through 31000
# removing stopwords from 31000 through 31100
# removing stopwords from 31100 through 31200
# removing stopwords from 31200 through 31300
# removing stopwords from 31300 through 31400
# removing stopwords from 31400 through 31500
# removing stopwords from 31500 through 31600
# removing stopwords from 31600 through 31700
# removing stopwords from 31700 through 31800
# removing stopwords from 31800 through 31900
# removing stopwords from 31900 through 32000
# removing stopwords from 32000 through 32100
# removing stopwords from 32100 through 32200
# removing stopwords from 32200 through 32300
# removing stopwords from 32300 through 32400
# removing stopwords from 32400 through 32500
# removing stopwords from 32500 through 32600
# removing stopwords from 32600 through 32700
# removing stopwords from 32700 through 32800
# removing stopwords from 32800 through 32900
# removing stopwords from 32900 through 33000
# removing stopwords from 33000 through 33100
# removing stopwords from 33100 through 33200
# removing stopwords from 33200 through 33300
# removing stopwords from 33300 through 33400
# removing stopwords from 33400 through 33500
# removing stopwords from 33500 through 33600
# removing stopwords from 33600 through 33700
# removing stopwords from 33700 through 33800
# removing stopwords from 33800 through 33900
# removing stopwords from 33900 through 34000
# removing stopwords from 34000 through 34100
# removing stopwords from 34100 through 34200
# removing stopwords from 34200 through 34300
# removing stopwords from 34300 through 34400
# removing stopwords from 34400 through 34500
# removing stopwords from 34500 through 34600
# removing stopwords from 34600 through 34700
# removing stopwords from 34700 through 34800
# removing stopwords from 34800 through 34900
# removing stopwords from 34900 through 35000
# removing stopwords from 35000 through 35100
# removing stopwords from 35100 through 35200
# removing stopwords from 35200 through 35300
# removing stopwords from 35300 through 35400
# removing stopwords from 35400 through 35500
# removing stopwords from 35500 through 35600
# removing stopwords from 35600 through 35700
# removing stopwords from 35700 through 35800
# removing stopwords from 35800 through 35900
# removing stopwords from 35900 through 36000
# removing stopwords from 36000 through 36100
# removing stopwords from 36100 through 36200
# removing stopwords from 36200 through 36300
# removing stopwords from 36300 through 36400
# removing stopwords from 36400 through 36500
# removing stopwords from 36500 through 36600
# removing stopwords from 36600 through 36700
# removing stopwords from 36700 through 36800
# removing stopwords from 36800 through 36900
# removing stopwords from 36900 through 37000
# removing stopwords from 37000 through 37100
# removing stopwords from 37100 through 37200
# removing stopwords from 37200 through 37300
# removing stopwords from 37300 through 37400
# removing stopwords from 37400 through 37500
# removing stopwords from 37500 through 37600
# removing stopwords from 37600 through 37700
# removing stopwords from 37700 through 37800
# removing stopwords from 37800 through 37900
# removing stopwords from 37900 through 38000
# removing stopwords from 38000 through 38100
# removing stopwords from 38100 through 38200
# removing stopwords from 38200 through 38300
# removing stopwords from 38300 through 38400
# removing stopwords from 38400 through 38500
# removing stopwords from 38500 through 38600
# removing stopwords from 38600 through 38700
# removing stopwords from 38700 through 38800
# removing stopwords from 38800 through 38900
# removing stopwords from 38900 through 39000
# removing stopwords from 39000 through 39100
# removing stopwords from 39100 through 39200
# removing stopwords from 39200 through 39300
# removing stopwords from 39300 through 39400
# removing stopwords from 39400 through 39500
# removing stopwords from 39500 through 39600
# removing stopwords from 39600 through 39700
# removing stopwords from 39700 through 39800
# removing stopwords from 39800 through 39900
# removing stopwords from 39900 through 40000
# removing stopwords from 40000 through 40100
# removing stopwords from 40100 through 40200
# removing stopwords from 40200 through 40300
# removing stopwords from 40300 through 40400
# removing stopwords from 40400 through 40500
# removing stopwords from 40500 through 40600
# removing stopwords from 40600 through 40700
# removing stopwords from 40700 through 40800
# removing stopwords from 40800 through 40900
# removing stopwords from 40900 through 41000
# removing stopwords from 41000 through 41100
# removing stopwords from 41100 through 41200
# removing stopwords from 41200 through 41300
# removing stopwords from 41300 through 41400
# removing stopwords from 41400 through 41500
# removing stopwords from 41500 through 41600
# removing stopwords from 41600 through 41700
# removing stopwords from 41700 through 41800
# removing stopwords from 41800 through 41900
# removing stopwords from 41900 through 42000
# removing stopwords from 42000 through 42100
# removing stopwords from 42100 through 42200
# removing stopwords from 42200 through 42300
# removing stopwords from 42300 through 42400
# removing stopwords from 42400 through 42500
# removing stopwords from 42500 through 42600
# removing stopwords from 42600 through 42700
# removing stopwords from 42700 through 42800
# removing stopwords from 42800 through 42900
# removing stopwords from 42900 through 43000
# removing stopwords from 43000 through 43100
# removing stopwords from 43100 through 43200
# making bigrams from 0 through 100
# making bigrams from 100 through 200
# making bigrams from 200 through 300
# making bigrams from 300 through 400
# making bigrams from 400 through 500
# making bigrams from 500 through 600
# making bigrams from 600 through 700
# making bigrams from 700 through 800
# making bigrams from 800 through 900
# making bigrams from 900 through 1000
# making bigrams from 1000 through 1100
# making bigrams from 1100 through 1200
# making bigrams from 1200 through 1300
# making bigrams from 1300 through 1400
# making bigrams from 1400 through 1500
# making bigrams from 1500 through 1600
# making bigrams from 1600 through 1700
# making bigrams from 1700 through 1800
# making bigrams from 1800 through 1900
# making bigrams from 1900 through 2000
# making bigrams from 2000 through 2100
# making bigrams from 2100 through 2200
# making bigrams from 2200 through 2300
# making bigrams from 2300 through 2400
# making bigrams from 2400 through 2500
# making bigrams from 2500 through 2600
# making bigrams from 2600 through 2700
# making bigrams from 2700 through 2800
# making bigrams from 2800 through 2900
# making bigrams from 2900 through 3000
# making bigrams from 3000 through 3100
# making bigrams from 3100 through 3200
# making bigrams from 3200 through 3300
# making bigrams from 3300 through 3400
# making bigrams from 3400 through 3500
# making bigrams from 3500 through 3600
# making bigrams from 3600 through 3700
# making bigrams from 3700 through 3800
# making bigrams from 3800 through 3900
# making bigrams from 3900 through 4000
# making bigrams from 4000 through 4100
# making bigrams from 4100 through 4200
# making bigrams from 4200 through 4300
# making bigrams from 4300 through 4400
# making bigrams from 4400 through 4500
# making bigrams from 4500 through 4600
# making bigrams from 4600 through 4700
# making bigrams from 4700 through 4800
# making bigrams from 4800 through 4900
# making bigrams from 4900 through 5000
# making bigrams from 5000 through 5100
# making bigrams from 5100 through 5200
# making bigrams from 5200 through 5300
# making bigrams from 5300 through 5400
# making bigrams from 5400 through 5500
# making bigrams from 5500 through 5600
# making bigrams from 5600 through 5700
# making bigrams from 5700 through 5800
# making bigrams from 5800 through 5900
# making bigrams from 5900 through 6000
# making bigrams from 6000 through 6100
# making bigrams from 6100 through 6200
# making bigrams from 6200 through 6300
# making bigrams from 6300 through 6400
# making bigrams from 6400 through 6500
# making bigrams from 6500 through 6600
# making bigrams from 6600 through 6700
# making bigrams from 6700 through 6800
# making bigrams from 6800 through 6900
# making bigrams from 6900 through 7000
# making bigrams from 7000 through 7100
# making bigrams from 7100 through 7200
# making bigrams from 7200 through 7300
# making bigrams from 7300 through 7400
# making bigrams from 7400 through 7500
# making bigrams from 7500 through 7600
# making bigrams from 7600 through 7700
# making bigrams from 7700 through 7800
# making bigrams from 7800 through 7900
# making bigrams from 7900 through 8000
# making bigrams from 8000 through 8100
# making bigrams from 8100 through 8200
# making bigrams from 8200 through 8300
# making bigrams from 8300 through 8400
# making bigrams from 8400 through 8500
# making bigrams from 8500 through 8600
# making bigrams from 8600 through 8700
# making bigrams from 8700 through 8800
# making bigrams from 8800 through 8900
# making bigrams from 8900 through 9000
# making bigrams from 9000 through 9100
# making bigrams from 9100 through 9200
# making bigrams from 9200 through 9300
# making bigrams from 9300 through 9400
# making bigrams from 9400 through 9500
# making bigrams from 9500 through 9600
# making bigrams from 9600 through 9700
# making bigrams from 9700 through 9800
# making bigrams from 9800 through 9900
# making bigrams from 9900 through 10000
# making bigrams from 10000 through 10100
# making bigrams from 10100 through 10200
# making bigrams from 10200 through 10300
# making bigrams from 10300 through 10400
# making bigrams from 10400 through 10500
# making bigrams from 10500 through 10600
# making bigrams from 10600 through 10700
# making bigrams from 10700 through 10800
# making bigrams from 10800 through 10900
# making bigrams from 10900 through 11000
# making bigrams from 11000 through 11100
# making bigrams from 11100 through 11200
# making bigrams from 11200 through 11300
# making bigrams from 11300 through 11400
# making bigrams from 11400 through 11500
# making bigrams from 11500 through 11600
# making bigrams from 11600 through 11700
# making bigrams from 11700 through 11800
# making bigrams from 11800 through 11900
# making bigrams from 11900 through 12000
# making bigrams from 12000 through 12100
# making bigrams from 12100 through 12200
# making bigrams from 12200 through 12300
# making bigrams from 12300 through 12400
# making bigrams from 12400 through 12500
# making bigrams from 12500 through 12600
# making bigrams from 12600 through 12700
# making bigrams from 12700 through 12800
# making bigrams from 12800 through 12900
# making bigrams from 12900 through 13000
# making bigrams from 13000 through 13100
# making bigrams from 13100 through 13200
# making bigrams from 13200 through 13300
# making bigrams from 13300 through 13400
# making bigrams from 13400 through 13500
# making bigrams from 13500 through 13600
# making bigrams from 13600 through 13700
# making bigrams from 13700 through 13800
# making bigrams from 13800 through 13900
# making bigrams from 13900 through 14000
# making bigrams from 14000 through 14100
# making bigrams from 14100 through 14200
# making bigrams from 14200 through 14300
# making bigrams from 14300 through 14400
# making bigrams from 14400 through 14500
# making bigrams from 14500 through 14600
# making bigrams from 14600 through 14700
# making bigrams from 14700 through 14800
# making bigrams from 14800 through 14900
# making bigrams from 14900 through 15000
# making bigrams from 15000 through 15100
# making bigrams from 15100 through 15200
# making bigrams from 15200 through 15300
# making bigrams from 15300 through 15400
# making bigrams from 15400 through 15500
# making bigrams from 15500 through 15600
# making bigrams from 15600 through 15700
# making bigrams from 15700 through 15800
# making bigrams from 15800 through 15900
# making bigrams from 15900 through 16000
# making bigrams from 16000 through 16100
# making bigrams from 16100 through 16200
# making bigrams from 16200 through 16300
# making bigrams from 16300 through 16400
# making bigrams from 16400 through 16500
# making bigrams from 16500 through 16600
# making bigrams from 16600 through 16700
# making bigrams from 16700 through 16800
# making bigrams from 16800 through 16900
# making bigrams from 16900 through 17000
# making bigrams from 17000 through 17100
# making bigrams from 17100 through 17200
# making bigrams from 17200 through 17300
# making bigrams from 17300 through 17400
# making bigrams from 17400 through 17500
# making bigrams from 17500 through 17600
# making bigrams from 17600 through 17700
# making bigrams from 17700 through 17800
# making bigrams from 17800 through 17900
# making bigrams from 17900 through 18000
# making bigrams from 18000 through 18100
# making bigrams from 18100 through 18200
# making bigrams from 18200 through 18300
# making bigrams from 18300 through 18400
# making bigrams from 18400 through 18500
# making bigrams from 18500 through 18600
# making bigrams from 18600 through 18700
# making bigrams from 18700 through 18800
# making bigrams from 18800 through 18900
# making bigrams from 18900 through 19000
# making bigrams from 19000 through 19100
# making bigrams from 19100 through 19200
# making bigrams from 19200 through 19300
# making bigrams from 19300 through 19400
# making bigrams from 19400 through 19500
# making bigrams from 19500 through 19600
# making bigrams from 19600 through 19700
# making bigrams from 19700 through 19800
# making bigrams from 19800 through 19900
# making bigrams from 19900 through 20000
# making bigrams from 20000 through 20100
# making bigrams from 20100 through 20200
# making bigrams from 20200 through 20300
# making bigrams from 20300 through 20400
# making bigrams from 20400 through 20500
# making bigrams from 20500 through 20600
# making bigrams from 20600 through 20700
# making bigrams from 20700 through 20800
# making bigrams from 20800 through 20900
# making bigrams from 20900 through 21000
# making bigrams from 21000 through 21100
# making bigrams from 21100 through 21200
# making bigrams from 21200 through 21300
# making bigrams from 21300 through 21400
# making bigrams from 21400 through 21500
# making bigrams from 21500 through 21600
# making bigrams from 21600 through 21700
# making bigrams from 21700 through 21800
# making bigrams from 21800 through 21900
# making bigrams from 21900 through 22000
# making bigrams from 22000 through 22100
# making bigrams from 22100 through 22200
# making bigrams from 22200 through 22300
# making bigrams from 22300 through 22400
# making bigrams from 22400 through 22500
# making bigrams from 22500 through 22600
# making bigrams from 22600 through 22700
# making bigrams from 22700 through 22800
# making bigrams from 22800 through 22900
# making bigrams from 22900 through 23000
# making bigrams from 23000 through 23100
# making bigrams from 23100 through 23200
# making bigrams from 23200 through 23300
# making bigrams from 23300 through 23400
# making bigrams from 23400 through 23500
# making bigrams from 23500 through 23600
# making bigrams from 23600 through 23700
# making bigrams from 23700 through 23800
# making bigrams from 23800 through 23900
# making bigrams from 23900 through 24000
# making bigrams from 24000 through 24100
# making bigrams from 24100 through 24200
# making bigrams from 24200 through 24300
# making bigrams from 24300 through 24400
# making bigrams from 24400 through 24500
# making bigrams from 24500 through 24600
# making bigrams from 24600 through 24700
# making bigrams from 24700 through 24800
# making bigrams from 24800 through 24900
# making bigrams from 24900 through 25000
# making bigrams from 25000 through 25100
# making bigrams from 25100 through 25200
# making bigrams from 25200 through 25300
# making bigrams from 25300 through 25400
# making bigrams from 25400 through 25500
# making bigrams from 25500 through 25600
# making bigrams from 25600 through 25700
# making bigrams from 25700 through 25800
# making bigrams from 25800 through 25900
# making bigrams from 25900 through 26000
# making bigrams from 26000 through 26100
# making bigrams from 26100 through 26200
# making bigrams from 26200 through 26300
# making bigrams from 26300 through 26400
# making bigrams from 26400 through 26500
# making bigrams from 26500 through 26600
# making bigrams from 26600 through 26700
# making bigrams from 26700 through 26800
# making bigrams from 26800 through 26900
# making bigrams from 26900 through 27000
# making bigrams from 27000 through 27100
# making bigrams from 27100 through 27200
# making bigrams from 27200 through 27300
# making bigrams from 27300 through 27400
# making bigrams from 27400 through 27500
# making bigrams from 27500 through 27600
# making bigrams from 27600 through 27700
# making bigrams from 27700 through 27800
# making bigrams from 27800 through 27900
# making bigrams from 27900 through 28000
# making bigrams from 28000 through 28100
# making bigrams from 28100 through 28200
# making bigrams from 28200 through 28300
# making bigrams from 28300 through 28400
# making bigrams from 28400 through 28500
# making bigrams from 28500 through 28600
# making bigrams from 28600 through 28700
# making bigrams from 28700 through 28800
# making bigrams from 28800 through 28900
# making bigrams from 28900 through 29000
# making bigrams from 29000 through 29100
# making bigrams from 29100 through 29200
# making bigrams from 29200 through 29300
# making bigrams from 29300 through 29400
# making bigrams from 29400 through 29500
# making bigrams from 29500 through 29600
# making bigrams from 29600 through 29700
# making bigrams from 29700 through 29800
# making bigrams from 29800 through 29900
# making bigrams from 29900 through 30000
# making bigrams from 30000 through 30100
# making bigrams from 30100 through 30200
# making bigrams from 30200 through 30300
# making bigrams from 30300 through 30400
# making bigrams from 30400 through 30500
# making bigrams from 30500 through 30600
# making bigrams from 30600 through 30700
# making bigrams from 30700 through 30800
# making bigrams from 30800 through 30900
# making bigrams from 30900 through 31000
# making bigrams from 31000 through 31100
# making bigrams from 31100 through 31200
# making bigrams from 31200 through 31300
# making bigrams from 31300 through 31400
# making bigrams from 31400 through 31500
# making bigrams from 31500 through 31600
# making bigrams from 31600 through 31700
# making bigrams from 31700 through 31800
# making bigrams from 31800 through 31900
# making bigrams from 31900 through 32000
# making bigrams from 32000 through 32100
# making bigrams from 32100 through 32200
# making bigrams from 32200 through 32300
# making bigrams from 32300 through 32400
# making bigrams from 32400 through 32500
# making bigrams from 32500 through 32600
# making bigrams from 32600 through 32700
# making bigrams from 32700 through 32800
# making bigrams from 32800 through 32900
# making bigrams from 32900 through 33000
# making bigrams from 33000 through 33100
# making bigrams from 33100 through 33200
# making bigrams from 33200 through 33300
# making bigrams from 33300 through 33400
# making bigrams from 33400 through 33500
# making bigrams from 33500 through 33600
# making bigrams from 33600 through 33700
# making bigrams from 33700 through 33800
# making bigrams from 33800 through 33900
# making bigrams from 33900 through 34000
# making bigrams from 34000 through 34100
# making bigrams from 34100 through 34200
# making bigrams from 34200 through 34300
# making bigrams from 34300 through 34400
# making bigrams from 34400 through 34500
# making bigrams from 34500 through 34600
# making bigrams from 34600 through 34700
# making bigrams from 34700 through 34800
# making bigrams from 34800 through 34900
# making bigrams from 34900 through 35000
# making bigrams from 35000 through 35100
# making bigrams from 35100 through 35200
# making bigrams from 35200 through 35300
# making bigrams from 35300 through 35400
# making bigrams from 35400 through 35500
# making bigrams from 35500 through 35600
# making bigrams from 35600 through 35700
# making bigrams from 35700 through 35800
# making bigrams from 35800 through 35900
# making bigrams from 35900 through 36000
# making bigrams from 36000 through 36100
# making bigrams from 36100 through 36200
# making bigrams from 36200 through 36300
# making bigrams from 36300 through 36400
# making bigrams from 36400 through 36500
# making bigrams from 36500 through 36600
# making bigrams from 36600 through 36700
# making bigrams from 36700 through 36800
# making bigrams from 36800 through 36900
# making bigrams from 36900 through 37000
# making bigrams from 37000 through 37100
# making bigrams from 37100 through 37200
# making bigrams from 37200 through 37300
# making bigrams from 37300 through 37400
# making bigrams from 37400 through 37500
# making bigrams from 37500 through 37600
# making bigrams from 37600 through 37700
# making bigrams from 37700 through 37800
# making bigrams from 37800 through 37900
# making bigrams from 37900 through 38000
# making bigrams from 38000 through 38100
# making bigrams from 38100 through 38200
# making bigrams from 38200 through 38300
# making bigrams from 38300 through 38400
# making bigrams from 38400 through 38500
# making bigrams from 38500 through 38600
# making bigrams from 38600 through 38700
# making bigrams from 38700 through 38800
# making bigrams from 38800 through 38900
# making bigrams from 38900 through 39000
# making bigrams from 39000 through 39100
# making bigrams from 39100 through 39200
# making bigrams from 39200 through 39300
# making bigrams from 39300 through 39400
# making bigrams from 39400 through 39500
# making bigrams from 39500 through 39600
# making bigrams from 39600 through 39700
# making bigrams from 39700 through 39800
# making bigrams from 39800 through 39900
# making bigrams from 39900 through 40000
# making bigrams from 40000 through 40100
# making bigrams from 40100 through 40200
# making bigrams from 40200 through 40300
# making bigrams from 40300 through 40400
# making bigrams from 40400 through 40500
# making bigrams from 40500 through 40600
# making bigrams from 40600 through 40700
# making bigrams from 40700 through 40800
# making bigrams from 40800 through 40900
# making bigrams from 40900 through 41000
# making bigrams from 41000 through 41100
# making bigrams from 41100 through 41200
# making bigrams from 41200 through 41300
# making bigrams from 41300 through 41400
# making bigrams from 41400 through 41500
# making bigrams from 41500 through 41600
# making bigrams from 41600 through 41700
# making bigrams from 41700 through 41800
# making bigrams from 41800 through 41900
# making bigrams from 41900 through 42000
# making bigrams from 42000 through 42100
# making bigrams from 42100 through 42200
# making bigrams from 42200 through 42300
# making bigrams from 42300 through 42400
# making bigrams from 42400 through 42500
# making bigrams from 42500 through 42600
# making bigrams from 42600 through 42700
# making bigrams from 42700 through 42800
# making bigrams from 42800 through 42900
# making bigrams from 42900 through 43000
# making bigrams from 43000 through 43100
# making bigrams from 43100 through 43200
# removing make trigram from 0 through 100
# removing make trigram from 10000 through 10100
# removing make trigram from 20000 through 20100
# removing make trigram from 30000 through 30100
# removing make trigram from 40000 through 40100
# removing make trigram from 50000 through 50100
# removing make trigram from 60000 through 60100
# removing make trigram from 70000 through 70100
# removing make trigram from 80000 through 80100
# removing make trigram from 90000 through 90100
# removing make trigram from 100000 through 100100
# removing make trigram from 110000 through 110100
# removing make trigram from 120000 through 120100
# removing make trigram from 130000 through 130100
# removing make trigram from 140000 through 140100
# removing make trigram from 150000 through 150100
# removing make trigram from 160000 through 160100
# removing make trigram from 170000 through 170100
# removing make trigram from 180000 through 180100
# removing make trigram from 190000 through 190100
# removing make trigram from 200000 through 200100
# removing make trigram from 210000 through 210100
# removing make trigram from 220000 through 220100
# removing make trigram from 230000 through 230100
# removing make trigram from 240000 through 240100
# removing make trigram from 250000 through 250100
# removing make trigram from 260000 through 260100
# removing make trigram from 270000 through 270100
# removing make trigram from 280000 through 280100
# removing make trigram from 290000 through 290100
# removing make trigram from 300000 through 300100
# removing make trigram from 310000 through 310100
# removing make trigram from 320000 through 320100
# removing make trigram from 330000 through 330100
# removing make trigram from 340000 through 340100
# removing make trigram from 350000 through 350100
# removing make trigram from 360000 through 360100
# removing make trigram from 370000 through 370100
# removing make trigram from 380000 through 380100
# removing make trigram from 390000 through 390100
# removing make trigram from 400000 through 400100
# removing make trigram from 410000 through 410100
# removing make trigram from 420000 through 420100
# removing make trigram from 430000 through 430100
# removing make trigram from 440000 through 440100
# removing make trigram from 450000 through 450100
# removing make trigram from 460000 through 460100
# removing make trigram from 470000 through 470100
# removing make trigram from 480000 through 480100
# removing make trigram from 490000 through 490100
# removing make trigram from 500000 through 500100
# removing make trigram from 510000 through 510100
# removing make trigram from 520000 through 520100
# removing make trigram from 530000 through 530100
# removing make trigram from 540000 through 540100
# removing make trigram from 550000 through 550100
# removing make trigram from 560000 through 560100
# removing make trigram from 570000 through 570100
# removing make trigram from 580000 through 580100
# removing make trigram from 590000 through 590100
# removing make trigram from 600000 through 600100
# removing make trigram from 610000 through 610100
# removing make trigram from 620000 through 620100
# removing make trigram from 630000 through 630100
# removing make trigram from 640000 through 640100
# removing make trigram from 650000 through 650100
# removing make trigram from 660000 through 660100
# removing make trigram from 670000 through 670100
# removing make trigram from 680000 through 680100
# removing make trigram from 690000 through 690100
# removing make trigram from 700000 through 700100
# removing make trigram from 710000 through 710100
# removing make trigram from 720000 through 720100
# removing make trigram from 730000 through 730100
# removing make trigram from 740000 through 740100
# removing make trigram from 750000 through 750100
# removing make trigram from 760000 through 760100
# removing make trigram from 770000 through 770100
# removing make trigram from 780000 through 780100
# removing make trigram from 790000 through 790100
# removing make trigram from 800000 through 800100
# removing make trigram from 810000 through 810100
# removing make trigram from 820000 through 820100
# removing make trigram from 830000 through 830100
# removing make trigram from 840000 through 840100
# removing make trigram from 850000 through 850100
# removing make trigram from 860000 through 860100
# removing make trigram from 870000 through 870100
# removing make trigram from 880000 through 880100
# removing make trigram from 890000 through 890100
# removing make trigram from 900000 through 900100
# removing make trigram from 910000 through 910100
# removing make trigram from 920000 through 920100
# removing make trigram from 930000 through 930100
# removing make trigram from 940000 through 940100
# removing make trigram from 950000 through 950100
# removing make trigram from 960000 through 960100
# removing make trigram from 970000 through 970100
# removing make trigram from 980000 through 980100
# removing make trigram from 990000 through 990100
# removing make trigram from 1000000 through 1000100
# removing make trigram from 1010000 through 1010100
# removing make trigram from 1020000 through 1020100
# removing make trigram from 1030000 through 1030100
# removing make trigram from 1040000 through 1040100
# removing make trigram from 1050000 through 1050100
# removing make trigram from 1060000 through 1060100
# removing make trigram from 1070000 through 1070100
# removing make trigram from 1080000 through 1080100
# removing make trigram from 1090000 through 1090100
# removing make trigram from 1100000 through 1100100
# removing make trigram from 1110000 through 1110100
# removing make trigram from 1120000 through 1120100
# removing make trigram from 1130000 through 1130100
# removing make trigram from 1140000 through 1140100
# removing make trigram from 1150000 through 1150100
# removing make trigram from 1160000 through 1160100
# removing make trigram from 1170000 through 1170100
# removing make trigram from 1180000 through 1180100
# removing make trigram from 1190000 through 1190100
# removing make trigram from 1200000 through 1200100
# removing make trigram from 1210000 through 1210100
# removing make trigram from 1220000 through 1220100
# removing make trigram from 1230000 through 1230100
# removing make trigram from 1240000 through 1240100
# removing make trigram from 1250000 through 1250100
# removing make trigram from 1260000 through 1260100
# removing make trigram from 1270000 through 1270100
# removing make trigram from 1280000 through 1280100
# removing make trigram from 1290000 through 1290100
# removing make trigram from 1300000 through 1300100
# removing make trigram from 1310000 through 1310100
# removing make trigram from 1320000 through 1320100
# removing make trigram from 1330000 through 1330100
# removing make trigram from 1340000 through 1340100
# removing make trigram from 1350000 through 1350100
# removing make trigram from 1360000 through 1360100
# removing make trigram from 1370000 through 1370100
# removing make trigram from 1380000 through 1380100
# removing make trigram from 1390000 through 1390100
# removing make trigram from 1400000 through 1400100
# removing make trigram from 1410000 through 1410100
# removing make trigram from 1420000 through 1420100
# removing make trigram from 1430000 through 1430100
# removing make trigram from 1440000 through 1440100
# removing make trigram from 1450000 through 1450100
# removing make trigram from 1460000 through 1460100
# removing make trigram from 1470000 through 1470100
# removing make trigram from 1480000 through 1480100
# removing make trigram from 1490000 through 1490100
# removing make trigram from 1500000 through 1500100
# removing make trigram from 1510000 through 1510100
# removing make trigram from 1520000 through 1520100
# removing make trigram from 1530000 through 1530100
# removing make trigram from 1540000 through 1540100
# removing make trigram from 1550000 through 1550100
# removing make trigram from 1560000 through 1560100
# removing make trigram from 1570000 through 1570100
# removing make trigram from 1580000 through 1580100
# removing make trigram from 1590000 through 1590100
# removing make trigram from 1600000 through 1600100
# removing make trigram from 1610000 through 1610100
# removing make trigram from 1620000 through 1620100
# removing make trigram from 1630000 through 1630100
# removing make trigram from 1640000 through 1640100
# removing make trigram from 1650000 through 1650100
# removing make trigram from 1660000 through 1660100
# removing make trigram from 1670000 through 1670100
# removing make trigram from 1680000 through 1680100
# removing make trigram from 1690000 through 1690100
# removing make trigram from 1700000 through 1700100
# removing make trigram from 1710000 through 1710100
# removing make trigram from 1720000 through 1720100
# removing make trigram from 1730000 through 1730100
# removing make trigram from 1740000 through 1740100
# removing make trigram from 1750000 through 1750100
# removing make trigram from 1760000 through 1760100
# removing make trigram from 1770000 through 1770100
# removing make trigram from 1780000 through 1780100
# removing make trigram from 1790000 through 1790100
# removing make trigram from 1800000 through 1800100
# removing make trigram from 1810000 through 1810100
# removing make trigram from 1820000 through 1820100
# removing make trigram from 1830000 through 1830100
# removing make trigram from 1840000 through 1840100
# removing make trigram from 1850000 through 1850100
# removing make trigram from 1860000 through 1860100
# removing make trigram from 1870000 through 1870100
# removing make trigram from 1880000 through 1880100
# removing make trigram from 1890000 through 1890100
# removing make trigram from 1900000 through 1900100
# removing make trigram from 1910000 through 1910100
# removing make trigram from 1920000 through 1920100
# removing make trigram from 1930000 through 1930100
# removing make trigram from 1940000 through 1940100
# removing make trigram from 1950000 through 1950100
# removing make trigram from 1960000 through 1960100
# removing make trigram from 1970000 through 1970100
# removing make trigram from 1980000 through 1980100
# removing make trigram from 1990000 through 1990100
# removing make trigram from 2000000 through 2000100
# removing make trigram from 2010000 through 2010100
# removing make trigram from 2020000 through 2020100
# removing make trigram from 2030000 through 2030100
# removing make trigram from 2040000 through 2040100
# removing make trigram from 2050000 through 2050100
# removing make trigram from 2060000 through 2060100
# removing make trigram from 2070000 through 2070100
# removing make trigram from 2080000 through 2080100
# removing make trigram from 2090000 through 2090100
# removing make trigram from 2100000 through 2100100
# removing make trigram from 2110000 through 2110100
# removing make trigram from 2120000 through 2120100
# removing make trigram from 2130000 through 2130100
# removing make trigram from 2140000 through 2140100
# removing make trigram from 2150000 through 2150100
# removing make trigram from 2160000 through 2160100
# removing make trigram from 2170000 through 2170100
# removing make trigram from 2180000 through 2180100
# removing make trigram from 2190000 through 2190100
# removing make trigram from 2200000 through 2200100
# removing make trigram from 2210000 through 2210100
# removing make trigram from 2220000 through 2220100
# removing make trigram from 2230000 through 2230100
# removing make trigram from 2240000 through 2240100
# removing make trigram from 2250000 through 2250100
# removing make trigram from 2260000 through 2260100
# removing make trigram from 2270000 through 2270100
# removing make trigram from 2280000 through 2280100
# removing make trigram from 2290000 through 2290100
# removing make trigram from 2300000 through 2300100
# removing make trigram from 2310000 through 2310100
# removing make trigram from 2320000 through 2320100
# removing make trigram from 2330000 through 2330100
# removing make trigram from 2340000 through 2340100
# removing make trigram from 2350000 through 2350100
# removing make trigram from 2360000 through 2360100
# removing make trigram from 2370000 through 2370100
# removing make trigram from 2380000 through 2380100
# removing make trigram from 2390000 through 2390100
# removing make trigram from 2400000 through 2400100
# removing make trigram from 2410000 through 2410100
# removing make trigram from 2420000 through 2420100
# removing make trigram from 2430000 through 2430100
# removing make trigram from 2440000 through 2440100
# removing make trigram from 2450000 through 2450100
# removing make trigram from 2460000 through 2460100
# removing make trigram from 2470000 through 2470100
# removing make trigram from 2480000 through 2480100
# removing make trigram from 2490000 through 2490100
# removing make trigram from 2500000 through 2500100
# removing make trigram from 2510000 through 2510100
# removing make trigram from 2520000 through 2520100
# removing make trigram from 2530000 through 2530100
# removing make trigram from 2540000 through 2540100
# removing make trigram from 2550000 through 2550100
# removing make trigram from 2560000 through 2560100
# removing make trigram from 2570000 through 2570100
# removing make trigram from 2580000 through 2580100
# removing make trigram from 2590000 through 2590100
# removing make trigram from 2600000 through 2600100
# removing make trigram from 2610000 through 2610100
# removing make trigram from 2620000 through 2620100
# removing make trigram from 2630000 through 2630100
# removing make trigram from 2640000 through 2640100
# removing make trigram from 2650000 through 2650100
# removing make trigram from 2660000 through 2660100
# removing make trigram from 2670000 through 2670100
# removing make trigram from 2680000 through 2680100
# removing make trigram from 2690000 through 2690100
# removing make trigram from 2700000 through 2700100
# removing make trigram from 2710000 through 2710100
# removing make trigram from 2720000 through 2720100
# removing make trigram from 2730000 through 2730100
# removing make trigram from 2740000 through 2740100
# removing make trigram from 2750000 through 2750100
# removing make trigram from 2760000 through 2760100
# removing make trigram from 2770000 through 2770100
# removing make trigram from 2780000 through 2780100
# removing make trigram from 2790000 through 2790100
# removing make trigram from 2800000 through 2800100
# removing make trigram from 2810000 through 2810100
# removing make trigram from 2820000 through 2820100
# removing make trigram from 2830000 through 2830100
# removing make trigram from 2840000 through 2840100
# removing make trigram from 2850000 through 2850100
# removing make trigram from 2860000 through 2860100
# removing make trigram from 2870000 through 2870100
# removing make trigram from 2880000 through 2880100
# removing make trigram from 2890000 through 2890100
# removing make trigram from 2900000 through 2900100
# removing make trigram from 2910000 through 2910100
# removing make trigram from 2920000 through 2920100
# removing make trigram from 2930000 through 2930100
# removing make trigram from 2940000 through 2940100
# removing make trigram from 2950000 through 2950100
# removing make trigram from 2960000 through 2960100
# removing make trigram from 2970000 through 2970100
# removing make trigram from 2980000 through 2980100
# removing make trigram from 2990000 through 2990100
# removing make trigram from 3000000 through 3000100
# removing make trigram from 3010000 through 3010100
# removing make trigram from 3020000 through 3020100
# removing make trigram from 3030000 through 3030100
# removing make trigram from 3040000 through 3040100
# removing make trigram from 3050000 through 3050100
# removing make trigram from 3060000 through 3060100
# removing make trigram from 3070000 through 3070100
# removing make trigram from 3080000 through 3080100
# removing make trigram from 3090000 through 3090100
# removing make trigram from 3100000 through 3100100
# removing make trigram from 3110000 through 3110100
# removing make trigram from 3120000 through 3120100
# removing make trigram from 3130000 through 3130100
# removing make trigram from 3140000 through 3140100
# removing make trigram from 3150000 through 3150100
# removing make trigram from 3160000 through 3160100
# removing make trigram from 3170000 through 3170100
# removing make trigram from 3180000 through 3180100
# removing make trigram from 3190000 through 3190100
# removing make trigram from 3200000 through 3200100
# removing make trigram from 3210000 through 3210100
# removing make trigram from 3220000 through 3220100
# removing make trigram from 3230000 through 3230100
# removing make trigram from 3240000 through 3240100
# removing make trigram from 3250000 through 3250100
# removing make trigram from 3260000 through 3260100
# removing make trigram from 3270000 through 3270100
# removing make trigram from 3280000 through 3280100
# removing make trigram from 3290000 through 3290100
# removing make trigram from 3300000 through 3300100
# removing make trigram from 3310000 through 3310100
# removing make trigram from 3320000 through 3320100
# removing make trigram from 3330000 through 3330100
# removing make trigram from 3340000 through 3340100
# removing make trigram from 3350000 through 3350100
# removing make trigram from 3360000 through 3360100
# removing make trigram from 3370000 through 3370100
# removing make trigram from 3380000 through 3380100
# removing make trigram from 3390000 through 3390100
# removing make trigram from 3400000 through 3400100
# removing make trigram from 3410000 through 3410100
# removing make trigram from 3420000 through 3420100
# removing make trigram from 3430000 through 3430100
# removing make trigram from 3440000 through 3440100
# removing make trigram from 3450000 through 3450100
# removing make trigram from 3460000 through 3460100
# removing make trigram from 3470000 through 3470100
# removing make trigram from 3480000 through 3480100
# removing make trigram from 3490000 through 3490100
# removing make trigram from 3500000 through 3500100
# removing make trigram from 3510000 through 3510100
# removing make trigram from 3520000 through 3520100
# removing make trigram from 3530000 through 3530100
# removing make trigram from 3540000 through 3540100
# removing make trigram from 3550000 through 3550100
# removing make trigram from 3560000 through 3560100
# removing make trigram from 3570000 through 3570100
# removing make trigram from 3580000 through 3580100
# removing make trigram from 3590000 through 3590100
# removing make trigram from 3600000 through 3600100
# removing make trigram from 3610000 through 3610100
# removing make trigram from 3620000 through 3620100
# removing make trigram from 3630000 through 3630100
# removing make trigram from 3640000 through 3640100
# removing make trigram from 3650000 through 3650100
# removing make trigram from 3660000 through 3660100
# removing make trigram from 3670000 through 3670100
# removing make trigram from 3680000 through 3680100
# removing make trigram from 3690000 through 3690100
# removing make trigram from 3700000 through 3700100
# removing make trigram from 3710000 through 3710100
# removing make trigram from 3720000 through 3720100
# removing make trigram from 3730000 through 3730100
# removing make trigram from 3740000 through 3740100
# removing make trigram from 3750000 through 3750100
# removing make trigram from 3760000 through 3760100
# removing make trigram from 3770000 through 3770100
# removing make trigram from 3780000 through 3780100
# removing make trigram from 3790000 through 3790100
# removing make trigram from 3800000 through 3800100
# removing make trigram from 3810000 through 3810100
# removing make trigram from 3820000 through 3820100
# removing make trigram from 3830000 through 3830100
# removing make trigram from 3840000 through 3840100
# removing make trigram from 3850000 through 3850100
# removing make trigram from 3860000 through 3860100
# removing make trigram from 3870000 through 3870100
# removing make trigram from 3880000 through 3880100
# removing make trigram from 3890000 through 3890100
# removing make trigram from 3900000 through 3900100
# removing make trigram from 3910000 through 3910100
# removing make trigram from 3920000 through 3920100
# removing make trigram from 3930000 through 3930100
# removing make trigram from 3940000 through 3940100
# removing make trigram from 3950000 through 3950100
# removing make trigram from 3960000 through 3960100
# removing make trigram from 3970000 through 3970100
# removing make trigram from 3980000 through 3980100
# removing make trigram from 3990000 through 3990100
# removing make trigram from 4000000 through 4000100
# removing make trigram from 4010000 through 4010100
# removing make trigram from 4020000 through 4020100
# removing make trigram from 4030000 through 4030100
# removing make trigram from 4040000 through 4040100
# removing make trigram from 4050000 through 4050100
# removing make trigram from 4060000 through 4060100
# removing make trigram from 4070000 through 4070100
# removing make trigram from 4080000 through 4080100
# removing make trigram from 4090000 through 4090100
# removing make trigram from 4100000 through 4100100
# removing make trigram from 4110000 through 4110100
# removing make trigram from 4120000 through 4120100
# removing make trigram from 4130000 through 4130100
# removing make trigram from 4140000 through 4140100
# removing make trigram from 4150000 through 4150100
# removing make trigram from 4160000 through 4160100
# removing make trigram from 4170000 through 4170100
# removing make trigram from 4180000 through 4180100
# removing make trigram from 4190000 through 4190100
# removing make trigram from 4200000 through 4200100
# removing make trigram from 4210000 through 4210100
# removing make trigram from 4220000 through 4220100
# removing make trigram from 4230000 through 4230100
# removing make trigram from 4240000 through 4240100
# removing make trigram from 4250000 through 4250100
# removing make trigram from 4260000 through 4260100
# removing make trigram from 4270000 through 4270100
# removing make trigram from 4280000 through 4280100
# removing make trigram from 4290000 through 4290100
# removing make trigram from 4300000 through 4300100
# removing make trigram from 4310000 through 4310100
# [['release', 'inform', 'design', 'pair', 'add_on', 'company', 'build', 'information_modele', 'product', 'design', 'authoring_tool', 'intend', 'well', 'automate', 'process', 'product', 'design', 'placement', 'mechanical', 'assembly', 'complex', 'product', 'build', 'infrastructure', 'model', 'say', 'informed', 'design', 'connect', 'design', 'manufacturing', 'workflow', 'allow', 'designer', 'specify', 'product', 'assembly', 'create', 'inventor', 'company', 'manufacture', 'authoring_tool', 'tool', 'say', 'architect', 'engineer', 'demand', 'long', 'time', 'inform', 'design', 'improve', 'certainty', 'say', 'general', 'manager', 'manufacture', 'inform', 'design', 'autodesk', 'press', 'event', 'announce', 'product', 'productization', 'key', 'concept', 'make', 'possible', 'fabricator', 'subcontractor', 'define', 'product', 'include', 'way', 'varied', 'remain', 'manufacturable', 'product', 'publish', 'architect', 'discover', 'use', 'design', 'inventor', 'use', 'autodesk', 'construction', 'cloud', 'collaboration', 'platform', 'go', 'inventor', 'say', 'autodesk', 'plan', 'make', 'direct', 'workflow', 'available', 'explain', 'informed', 'design', 'add', 'allow', 'inventor', 'export', 'fully', 'form', 'family', 'output', 'shortcoming', 'inventor', 'produce', 'category', 'family', 'name', 'void', 'body', 'coordinate', 'system', 'thing', 'say', 'informed', 'design', 'allow', 'customer', 'use', 'inventor', 'create', 'family', 'manually', 'place', 'family', 'require', 'construction', 'use', 'store', 'template', 'project', 'datum', 'capability', 'define', 'rule', 'template', 'enforce', 'rule', 'necessitate', 'use', 'solution', 'take_advantage', 'author', 'enforcement', 'component', 'say', 'informed', 'design', 'inventor', 'allow', 'building', 'product', 'design', 'engineer', 'automate', 'process', 'create', 'model', 'build', 'product', 'mechanical', 'equipment', 'assembly', 'component', 'unitized', 'curtainwall', 'even', 'build', 'component', 'escalator', 'inform', 'design', 'revit', 'allow', 'architect', 'engineer', 'virtual', 'design', 'construction', 'professional', 'place', 'build', 'product', 'model', 'see', 'parametric', 'building', 'product', 'object', 'fit', 'overall', 'project', 'user', 'perform', 'basic', 'clash_detection', 'assessment', 'able', 'confirm', 'specify', 'building', 'product', 'meet', 'project', 'requirement', 'compatible', 'instal', 'component', 'meet', 'industry', 'standard', 'longtime', 'demand', 'autodesk', 'user', 'design', 'world', 'demand', 'price', 'say', 'user', 'need', 'inventor', 'construction', 'use', 'inform', 'design', 'add', 'available', 'upfront', 'charge', 'inform', 'design', 'part', 'autodesk', 'design', 'make', 'platform', 'environment', 'ultimately', 'wind', 'charge', 'generate', 'output', 'say', 'want', 'charge', 'author', 'product', 'want', 'charge', 'place', 'instance', 'product', 'building', 'project', 'want', 'create', 'bill', 'material', 'shop_drawing', 'format', 'use', 'fabricate', 'think', 'point', 'create', 'value', 'customer', 'feel', 'right', 'thing', 'monetize', 'plan', 'token', 'rate', 'base', 'output', 'create', 'several', 'autodesk', 'customer', 'begin', 'test', 'inform', 'design', 'second', 'half', 'autodesk', 'inform', 'design', 'show', 'way', 'bring', 'customize', 'detail', 'good', 'aesthetic', 'quality', 'engineering', 'product', 'mass', 'produce', 'say', 'senior', 'product', 'manager', 'sustainability', 'consultant', 'work', 'mainly', 'design', 'green', 'home', 'design', 'constraint', 'curb', 'creativity', 'give', 'choice', 'know', 'work', 'international', 'datum', 'corporation', 'idc', 'provider', 'market', 'intelligence', 'advisory', 'service', 'event', 'information', 'technology', 'consumer', 'technology', 'market', 'testing', 'workflow', 'inform', 'design', 'connect', 'bidirectional', 'digital', 'thread', 'share', 'datum', 'aeco', 'ecosystem', 'partner', 'easy', 'optimize', 'supplier', 'performance', 'deliver', 'quality', 'product', 'service', 'complement', 'overall', 'design', ' ...

# %%
# Create Dictionary 
id2word = corpora.Dictionary(data_lemmatized)  
# Create Corpus 
texts = data_lemmatized  
# Term Document Frequency 
corpus = [id2word.doc2bow(text) for text in texts]  
# View 
print(corpus[:1])
# Out:
# [[(0, 1), (1, 2), (2, 2), (3, 1), (4, 1), (5, 1), (6, 5), (7, 1), (8, 1), (9, 3), (10, 3), (11, 1), (12, 2), (13, 3), (14, 7), (15, 2), (16, 3), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 5), (25, 5), (26, 1), (27, 1), (28, 1), (29, 4), (30, 1), (31, 1), (32, 1), (33, 1), (34, 3), (35, 1), (36, 1), (37, 1), (38, 4), (39, 1), (40, 1), (41, 2), (42, 1), (43, 5), (44, 1), (45, 1), (46, 1), (47, 1), (48, 6), (49, 1), (50, 1), (51, 1), (52, 3), (53, 1), (54, 3), (55, 2), (56, 1), (57, 3), (58, 25), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 2), (66, 1), (67, 1), (68, 1), (69, 3), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 2), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 4), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 1), (90, 1), (91, 1), (92, 1), (93, 1), (94, 1), (95, 1), (96, 1), (97, 1), (98, 2), (99, 10), (100, 1), (101, 1), (102, 4), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 8), (111, 1), (112, 1), (113, 1), (114, 1), (115, 1), (116, 3), (117, 2), (118, 1), (119, 1), (120, 2), (121, 1), (122, 2), (123, 1), (124, 1), (125, 2), (126, 2), (127, 3), (128, 1), (129, 1), (130, 1), (131, 1), (132, 1), (133, 1), (134, 3), (135, 2), (136, 1), (137, 1), (138, 1), (139, 1), (140, 1), (141, 1), (142, 3), (143, 1), (144, 2), (145, 2), (146, 1), (147, 1), (148, 1), (149, 1), (150, 2), (151, 2), (152, 17), (153, 1), (154, 1), (155, 4), (156, 1), (157, 1), (158, 2), (159, 1), (160, 2), (161, 1), (162, 1), (163, 1), (164, 1), (165, 1), (166, 1), (167, 2), (168, 11), (169, 2), (170, 1), (171, 1), (172, 2), (173, 1), (174, 1), (175, 1), (176, 1), (177, 1), (178, 1), (179, 2), (180, 1), (181, 1), (182, 1), (183, 1), (184, 1), (185, 1), (186, 1), (187, 2), (188, 2), (189, 1), (190, 1), (191, 2), (192, 1), (193, 1), (194, 1), (195, 1), (196, 1), (197, 1), (198, 1), (199, 1), (200, 7), (201, 3), (202, 1), (203, 1), (204, 1), (205, 1), (206, 1), (207, 1), (208, 3), (209, 2), (210, 1), (211, 1), (212, 2), (213, 3), (214, 1)]]

# %%
"""Readable dictionary"""
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('able', 1),
#   ('add', 2),
#   ('add_on', 2),
#   ('advisory', 1),
#   ('aeco', 1),
#   ('aesthetic', 1),
#   ('allow', 5),
#   ('also', 1),
#   ('announce', 1),
#   ('architect', 3),
#   ('assembly', 3),
#   ('assessment', 1),
#   ('author', 2),
#   ('authoring_tool', 3),
#   ('autodesk', 7),
#   ('automate', 2),
#   ('available', 3),
#   ('base', 1),
#   ('basic', 1),
#   ('begin', 1),
#   ('bidirectional', 1),
#   ('bill', 1),
#   ('body', 1),
#   ('bring', 1),
#   ('build', 5),
#   ('building', 5),
#   ('capability', 1),
#   ('category', 1),
#   ('certainty', 1),
#   ('charge', 4),
#   ('choice', 1),
#   ('clash_detection', 1),
#   ('cloud', 1),
#   ('collaboration', 1),
#   ('company', 3),
#   ('compatible', 1),
#   ('complement', 1),
#   ('complex', 1),
#   ('component', 4),
#   ('concept', 1),
#   ('confirm', 1),
#   ('connect', 2),
#   ('constraint', 1),
#   ('construction', 5),
#   ('consultant', 1),
#   ('consumer', 1),
#   ('coordinate', 1),
#   ('corporation', 1),
#   ('create', 6),
#   ('creativity', 1),
#   ('curb', 1),
#   ('curtainwall', 1),
#   ('customer', 3),
#   ('customize', 1),
#   ('datum', 3),
#   ('define', 2),
#   ('deliver', 1),
#   ('demand', 3),
#   ('design', 25),
#   ('designer', 1),
#   ('detail', 1),
#   ('digital', 1),
#   ('direct', 1),
#   ('discover', 1),
#   ('easy', 1),
#   ('ecosystem', 2),
#   ('energy', 1),
#   ('enforce', 1),
#   ('enforcement', 1),
#   ('engineer', 3),
#   ('engineering', 1),
#   ('environment', 1),
#   ('equipment', 1),
#   ('escalator', 1),
#   ('even', 1),
#   ('event', 2),
#   ('explain', 1),
#   ('explainer', 1),
#   ('export', 1),
#   ('fabricate', 1),
#   ('fabricator', 1),
#   ('family', 4),
#   ('feel', 1),
#   ('fit', 1),
#   ('form', 1),
#   ('format', 1),
#   ('fully', 1),
#   ('general', 1),
#   ('generate', 1),
#   ('give', 1),
#   ('go', 1),
#   ('good', 1),
#   ('green', 1),
#   ('half', 1),
#   ('home', 1),
#   ('idc', 1),
#   ('improve', 1),
#   ('include', 1),
#   ('industry', 2),
#   ('inform', 10),
#   ('information', 1),
#   ('information_modele', 1),
#   ('informed', 4),
#   ('infrastructure', 1),
#   ('insight', 1),
#   ('instal', 1),
#   ('instance', 1),
#   ('intelligence', 1),
#   ('intend', 1),
#   ('international', 1),
#   ('inventor', 8),
#   ('key', 1),
#   ('know', 1),
#   ('long', 1),
#   ('longtime', 1),
#   ('mainly', 1),
#   ('make', 3),
#   ('manager', 2),
#   ('manually', 1),
#   ('manufacturable', 1),
#   ('manufacture', 2),
#   ('manufacturing', 1),
#   ('market', 2),
#   ('mass', 1),
#   ('material', 1),
#   ('mechanical', 2),
#   ('meet', 2),
#   ('model', 3),
#   ('monetize', 1),
#   ('name', 1),
#   ('necessitate', 1),
#   ('need', 1),
#   ('object', 1),
#   ('optimize', 1),
#   ('output', 3),
#   ('overall', 2),
#   ('pair', 1),
#   ('parametric', 1),
#   ('part', 1),
#   ('partner', 1),
#   ('perform', 1),
#   ('performance', 1),
#   ('place', 3),
#   ('placement', 1),
#   ('plan', 2),
#   ('platform', 2),
#   ('point', 1),
#   ('possible', 1),
#   ('press', 1),
#   ('price', 1),
#   ('process', 2),
#   ('produce', 2),
#   ('product', 17),
#   ('productization', 1),
#   ('professional', 1),
#   ('project', 4),
#   ('provider', 1),
#   ('publish', 1),
#   ('quality', 2),
#   ('rate', 1),
#   ('release', 2),
#   ('remain', 1),
#   ('require', 1),
#   ('requirement', 1),
#   ('research', 1),
#   ('revit', 1),
#   ('right', 1),
#   ('rule', 2),
#   ('say', 11),
#   ('second', 2),
#   ('see', 1),
#   ('senior', 1),
#   ('service', 2),
#   ('several', 1),
#   ('share', 1),
#   ('shop_drawing', 1),
#   ('shortcoming', 1),
#   ('show', 1),
#   ('solution', 1),
#   ('specify', 2),
#   ('standard', 1),
#   ('store', 1),
#   ('subcontractor', 1),
#   ('supplier', 1),
#   ('sustainability', 1),
#   ('system', 1),
#   ('take_advantage', 1),
#   ('technology', 2),
#   ('template', 2),
#   ('test', 1),
#   ('testing', 1),
#   ('thing', 2),
#   ('think', 1),
#   ('thread', 1),
#   ('time', 1),
#   ('token', 1),
#   ('tool', 1),
#   ('ultimately', 1),
#   ('unitized', 1),
#   ('upfront', 1),
#   ('use', 7),
#   ('user', 3),
#   ('value', 1),
#   ('varied', 1),
#   ('vice_president', 1),
#   ('video', 1),
#   ('virtual', 1),
#   ('void', 1),
#   ('want', 3),
#   ('way', 2),
#   ('well', 1),
#   ('wind', 1),
#   ('work', 2),
#   ('workflow', 3),
#   ('world', 1)]]

# %%
"""Build topic model"""
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the keyword of topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.049*"year" + 0.040*"construction" + 0.037*"price" + 0.028*"increase" + '
#   '0.023*"market" + 0.016*"cost" + 0.013*"last" + 0.011*"industry" + '
#   '0.011*"rate" + 0.010*"report"'),
#  (1,
#   '0.082*"firm" + 0.050*"company" + 0.040*"market" + 0.025*"business" + '
#   '0.021*"revenue" + 0.021*"base" + 0.020*"year" + 0.018*"say" + 0.017*"top" + '
#   '0.016*"contractor"'),
#  (2,
#   '0.057*"water" + 0.021*"engineer" + 0.018*"corps" + 0.018*"damage" + '
#   '0.017*"system" + 0.016*"area" + 0.014*"repair" + 0.011*"emergency" + '
#   '0.010*"protection" + 0.009*"storm"'),
#  (3,
#   '0.097*"say" + 0.022*"work" + 0.015*"go" + 0.014*"time" + 0.014*"get" + '
#   '0.013*"year" + 0.013*"take" + 0.012*"make" + 0.009*"see" + 0.009*"add"'),
#  (4,
#   '0.034*"rule" + 0.032*"claim" + 0.026*"contractor" + 0.018*"law" + '
#   '0.017*"insurance" + 0.016*"court" + 0.015*"case" + 0.014*"pay" + '
#   '0.013*"issue" + 0.013*"file"'),
#  (5,
#   '0.046*"power" + 0.039*"plant" + 0.036*"energy" + 0.020*"utility" + '
#   '0.018*"unit" + 0.017*"oil" + 0.016*"fuel" + 0.015*"gas" + 0.013*"new" + '
#   '0.013*"transmission"'),
#  (6,
#   '0.052*"airport" + 0.049*"security" + 0.032*"line" + 0.026*"port" + '
#   '0.023*"station" + 0.023*"pipeline" + 0.021*"terminal" + 0.020*"system" + '
#   '0.019*"aviation" + 0.018*"rail"'),
#  (7,
#   '0.077*"design" + 0.027*"building" + 0.022*"team" + 0.020*"build" + '
#   '0.019*"system" + 0.019*"construction" + 0.017*"engineer" + 0.017*"use" + '
#   '0.016*"project" + 0.011*"owner"'),
#  (8,
#   '0.166*"project" + 0.085*"construction" + 0.083*"contract" + '
#   '0.053*"contractor" + 0.046*"bid" + 0.044*"work" + 0.035*"cost" + '
#   '0.021*"schedule" + 0.020*"estimate" + 0.017*"management"'),
#  (9,
#   '0.041*"say" + 0.030*"state" + 0.018*"federal" + 0.018*"plan" + '
#   '0.017*"program" + 0.014*"agency" + 0.014*"new" + 0.014*"project" + '
#   '0.014*"fund" + 0.013*"year"'),
#  (10,
#   '0.042*"building" + 0.025*"new" + 0.025*"city" + 0.023*"center" + '
#   '0.022*"facility" + 0.021*"sq" + 0.019*"build" + 0.017*"space" + '
#   '0.017*"site" + 0.017*"project"'),
#  (11,
#   '0.051*"bridge" + 0.020*"road" + 0.019*"tunnel" + 0.015*"project" + '
#   '0.015*"highway" + 0.015*"span" + 0.015*"design" + 0.014*"new" + '
#   '0.014*"long" + 0.013*"lane"'),
#  (12,
#   '0.081*"bill" + 0.038*"highway" + 0.033*"measure" + 0.031*"transportation" + '
#   '0.026*"legislation" + 0.024*"house" + 0.024*"vote" + 0.021*"committee" + '
#   '0.021*"pass" + 0.021*"tax"'),
#  (13,
#   '0.040*"worker" + 0.035*"safety" + 0.022*"union" + 0.018*"construction" + '
#   '0.017*"collapse" + 0.016*"report" + 0.015*"labor" + 0.015*"fire" + '
#   '0.015*"contractor" + 0.014*"crane"'),
#  (14,
#   '0.037*"engineer" + 0.028*"firm" + 0.026*"engineering" + 0.025*"former" + '
#   '0.024*"base" + 0.023*"chief" + 0.022*"director" + 0.021*"vice_president" + '
#   '0.020*"executive" + 0.019*"manager"'),
#  (15,
#   '0.028*"industry" + 0.013*"change" + 0.012*"develop" + 0.011*"risk" + '
#   '0.010*"many" + 0.009*"need" + 0.008*"well" + 0.008*"business" + '
#   '0.008*"practice" + 0.007*"code"'),
#  (16,
#   '0.037*"steel" + 0.029*"concrete" + 0.013*"use" + 0.012*"structural" + '
#   '0.012*"wall" + 0.011*"structure" + 0.010*"tower" + 0.010*"load" + '
#   '0.009*"high" + 0.009*"material"'),
#  (17,
#   '0.032*"system" + 0.030*"use" + 0.024*"com" + 0.022*"model" + 0.022*"tool" + '
#   '0.022*"equipment" + 0.021*"new" + 0.020*"datum" + 0.020*"software" + '
#   '0.019*"product"'),
#  (18,
#   '0.159*"seat" + 0.123*"stadium" + 0.065*"sport" + 0.062*"arena" + '
#   '0.041*"venue" + 0.027*"construction" + 0.025*"ecosystem" + 0.022*"boise" + '
#   '0.021*"sponsor" + 0.020*"music"'),
#  (19,
#   '0.053*"school" + 0.043*"program" + 0.038*"engineering" + 0.035*"student" + '
#   '0.035*"construction" + 0.026*"year" + 0.019*"award" + 0.018*"engineer" + '
#   '0.016*"industry" + 0.015*"civil"')]

# %%
"""Evaluate topic models"""
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  
# a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -10.579978397292168

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
